# %%
import tensorflow as tf
import matplotlib.pyplot as plt


import numpy as np
from keras.callbacks import ReduceLROnPlateau
from tensorflow.python.keras.layers import Flatten

mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
split_index = int(0.8 * len(x_train))
x_val, y_val = x_train[split_index:], y_train[split_index:]
x_train, y_train = x_train[:split_index], y_train[:split_index]

def train_val_plot(history_):
    loss     = history_.history['loss']
    val_loss = history_.history['val_loss']
    epochs   = range(len(loss))
    plt.figure()
    plt.plot  ( epochs,loss )
    plt.plot  ( epochs,val_loss )
    plt.title ('Training and validation loss')
def acc_plot(history_):
    acc = history_.history['accuracy']
    val_acc  = history.history[ 'val_accuracy' ]
    epochs   = range(len(acc))
    plt.figure()
    plt.plot  ( epochs,     acc )
    plt.plot  ( epochs, val_acc )
    plt.title ('Training and validation accuracy')

# %%
import os

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])
path = "D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt"
dir_ = os.path.dirname(path)
cp = tf.keras.callbacks.ModelCheckpoint(filepath=path, save_weights_only=True, verbose=1)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=15, batch_size=32, validation_data=(x_val, y_val), callbacks=[cp])
train_val_plot(history)
os.listdir(dir_)
# Out:
# Epoch 1/15
# 1481/1500 [============================>.] - ETA: 0s - loss: 0.2824 - accuracy: 0.9200
# Epoch 1: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.2808 - accuracy: 0.9204 - val_loss: 0.1529 - val_accuracy: 0.9554
# Epoch 2/15
# 1458/1500 [============================>.] - ETA: 0s - loss: 0.1227 - accuracy: 0.9639
# Epoch 2: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1218 - accuracy: 0.9641 - val_loss: 0.1148 - val_accuracy: 0.9665
# Epoch 3/15
# 1456/1500 [============================>.] - ETA: 0s - loss: 0.0858 - accuracy: 0.9744
# Epoch 3: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0860 - accuracy: 0.9743 - val_loss: 0.1020 - val_accuracy: 0.9696
# Epoch 4/15
# ...

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_val, y_val), callbacks=[cp])
train_val_plot(history)
# Out:
# Epoch 1/10
# 1482/1500 [============================>.] - ETA: 0s - loss: 0.2902 - accuracy: 0.9192
# Epoch 1: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.2887 - accuracy: 0.9195 - val_loss: 0.1595 - val_accuracy: 0.9534
# Epoch 2/10
# 1467/1500 [============================>.] - ETA: 0s - loss: 0.1302 - accuracy: 0.9619
# Epoch 2: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1298 - accuracy: 0.9621 - val_loss: 0.1265 - val_accuracy: 0.9616
# Epoch 3/10
# 1497/1500 [============================>.] - ETA: 0s - loss: 0.0880 - accuracy: 0.9738
# Epoch 3: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0881 - accuracy: 0.9738 - val_loss: 0.1098 - val_accuracy: 0.9690
# Epoch 4/10
# ...

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu', activity_regularizer=tf.keras.regularizers.l1(0.01)),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_val, y_val), callbacks=[cp])
train_val_plot(history)
acc_plot(history)
# Out:
# Epoch 1/10
# 1484/1500 [============================>.] - ETA: 0s - loss: 0.4939 - accuracy: 0.9228
# Epoch 1: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.4922 - accuracy: 0.9231 - val_loss: 0.2950 - val_accuracy: 0.9582
# Epoch 2/10
# 1497/1500 [============================>.] - ETA: 0s - loss: 0.2493 - accuracy: 0.9666
# Epoch 2: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2494 - accuracy: 0.9666 - val_loss: 0.2261 - val_accuracy: 0.9665
# Epoch 3/10
# 1499/1500 [============================>.] - ETA: 0s - loss: 0.1897 - accuracy: 0.9771
# Epoch 3: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1896 - accuracy: 0.9771 - val_loss: 0.1978 - val_accuracy: 0.9711
# Epoch 4/10
# ...

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu', activity_regularizer=tf.keras.regularizers.l1(0.01)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_val, y_val), callbacks=[cp])
train_val_plot(history)
acc_plot(history)
# Out:
# Epoch 1/10
# 1495/1500 [============================>.] - ETA: 0s - loss: 0.5415 - accuracy: 0.9121
# Epoch 1: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5411 - accuracy: 0.9121 - val_loss: 0.3179 - val_accuracy: 0.9573
# Epoch 2/10
# 1479/1500 [============================>.] - ETA: 0s - loss: 0.3071 - accuracy: 0.9568
# Epoch 2: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3067 - accuracy: 0.9567 - val_loss: 0.2505 - val_accuracy: 0.9661
# Epoch 3/10
# 1484/1500 [============================>.] - ETA: 0s - loss: 0.2518 - accuracy: 0.9654
# Epoch 3: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2517 - accuracy: 0.9655 - val_loss: 0.2239 - val_accuracy: 0.9696
# Epoch 4/10
# ...

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu', activity_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_val, y_val), callbacks=[cp])
train_val_plot(history)
acc_plot(history)
# Out:
# Epoch 1/10
# 1488/1500 [============================>.] - ETA: 0s - loss: 0.4637 - accuracy: 0.9301
# Epoch 1: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4624 - accuracy: 0.9304 - val_loss: 0.2719 - val_accuracy: 0.9661
# Epoch 2/10
# 1488/1500 [============================>.] - ETA: 0s - loss: 0.2513 - accuracy: 0.9658
# Epoch 2: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2514 - accuracy: 0.9658 - val_loss: 0.2249 - val_accuracy: 0.9685
# Epoch 3/10
# 1489/1500 [============================>.] - ETA: 0s - loss: 0.2013 - accuracy: 0.9740
# Epoch 3: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2011 - accuracy: 0.9740 - val_loss: 0.2031 - val_accuracy: 0.9704
# Epoch 4/10
# ...

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu', activity_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_val, y_val), callbacks=[cp])
train_val_plot(history)
acc_plot(history)
# Out:
# Epoch 1/10
# 1499/1500 [============================>.] - ETA: 0s - loss: 0.3640 - accuracy: 0.9116
# Epoch 1: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 6s 3ms/step - loss: 0.3640 - accuracy: 0.9116 - val_loss: 0.1933 - val_accuracy: 0.9614
# Epoch 2/10
# 1491/1500 [============================>.] - ETA: 0s - loss: 0.2028 - accuracy: 0.9563
# Epoch 2: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2028 - accuracy: 0.9563 - val_loss: 0.1553 - val_accuracy: 0.9678
# Epoch 3/10
# 1481/1500 [============================>.] - ETA: 0s - loss: 0.1631 - accuracy: 0.9663
# Epoch 3: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1634 - accuracy: 0.9663 - val_loss: 0.1402 - val_accuracy: 0.9739
# Epoch 4/10
# ...

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu', activity_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='softmax')
])
optimizer = tf.keras.optimizers.Adam(learning_rate=0.00015)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=20, batch_size=32, validation_data=(x_val, y_val), callbacks=[cp])
train_val_plot(history)
acc_plot(history)
# Out:
# Epoch 1/20
# 1491/1500 [============================>.] - ETA: 0s - loss: 0.6613 - accuracy: 0.8391
# Epoch 1: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.6599 - accuracy: 0.8394 - val_loss: 0.3382 - val_accuracy: 0.9286
# Epoch 2/20
# 1493/1500 [============================>.] - ETA: 0s - loss: 0.3428 - accuracy: 0.9218
# Epoch 2: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3427 - accuracy: 0.9218 - val_loss: 0.2616 - val_accuracy: 0.9437
# Epoch 3/20
# 1494/1500 [============================>.] - ETA: 0s - loss: 0.2750 - accuracy: 0.9386
# Epoch 3: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2750 - accuracy: 0.9386 - val_loss: 0.2213 - val_accuracy: 0.9525
# Epoch 4/20
# ...

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu', activity_regularizer=tf.keras.regularizers.l2(0.0001)),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(256, activation='relu', activity_regularizer=tf.keras.regularizers.l2(0.0001)),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='softmax')
])
optimizer = tf.keras.optimizers.Adam(learning_rate=0.00015)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=20, batch_size=24, validation_data=(x_val, y_val), callbacks=[cp])
train_val_plot(history)
acc_plot(history)
model.save('mnist_model.keras')
# Out:
# Epoch 1/20
# Exception ignored in: <function WeakKeyDictionary.__init__.<locals>.remove at 0x0000027BE8A8CDC0>
# Traceback (most recent call last):
#   File "D:\Anaconda\envs\Lab1_DL\lib\weakref.py", line 370, in remove
#     def remove(k, selfref=ref(self)):
#   File "_pydevd_bundle\\pydevd_cython_win32_39_64.pyx", line 1535, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "D:\PyCharm 2024.2.1\plugins\python-ce\helpers\pydev\_pydev_bundle\pydev_is_thread_alive.py", line 11, in is_thread_alive
#     return not t._is_stopped
# KeyboardInterrupt:
# 1196/2000 [================>.............] - ETA: 1s - loss: 0.8126 - accuracy: 0.7569
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 11
#       9 optimizer = tf.keras.optimizers.Adam(learning_rate=0.00015)
# ...

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu', activity_regularizer=tf.keras.regularizers.l2(0.0001)),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(256, activation='relu', activity_regularizer=tf.keras.regularizers.l2(0.0001)),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='softmax')
])
optimizer = tf.keras.optimizers.Adadelta(learning_rate=0.3)
reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.0001)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=20, batch_size=24, validation_data=(x_val, y_val), callbacks=[reduce, cp])
train_val_plot(history)
acc_plot(history)
#model.save('mnist_model.keras')
# Out:
# Epoch 1/20
# 1958/2000 [============================>.] - ETA: 0s - loss: 0.5307 - accuracy: 0.8430
# Epoch 1: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.5261 - accuracy: 0.8444 - val_loss: 0.2205 - val_accuracy: 0.9387 - lr: 0.3000
# Epoch 2/20
# 1970/2000 [============================>.] - ETA: 0s - loss: 0.2669 - accuracy: 0.9254
# Epoch 2: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.2663 - accuracy: 0.9256 - val_loss: 0.1668 - val_accuracy: 0.9542 - lr: 0.3000
# Epoch 3/20
# 1997/2000 [============================>.] - ETA: 0s - loss: 0.2111 - accuracy: 0.9418
# Epoch 3: saving model to D:\PycharmProjects\DeepLearning\Lab1\cp.ckpt
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.2110 - accuracy: 0.9419 - val_loss: 0.1433 - val_accuracy: 0.9618 - lr: 0.3000
# Epoch 4/20
# ...

# %%
# input_layer = tf.keras.Input(shape=(28, 28))
# layer1 = tf.keras.layers.Flatten()(input_layer)
# layer2 = tf.keras.layers.Dense(256, activation='relu')(layer1)
# layer3 = tf.keras.layers.Dense(128, activation='relu')(layer1)
# merge = tf.keras.layers.Concatenate()([layer2, layer3])
# output = tf.keras.layers.Dense(10, activation='softmax')(merge)
# func_model = tf.keras.Model(inputs=input_layer, outputs=output)

# %%
latest = tf.train.latest_checkpoint(dir_)
new_model = tf.keras.models.load_model('mnist_model.keras')
new_model.load_weights(latest)
new_model.evaluate(x_test, y_test, verbose=2)
model.evaluate(x_test, y_test, verbose=2)
for i in range(5):
    plt.imshow(x_test[i], cmap=plt.cm.binary)
    plt.show()
    prediction = model.predict(x_test[i:i+1])
    print(f"Predicted probabilities for image {i}:")
    print(prediction)
    print(f"Predicted class: {tf.argmax(prediction[0])}")
# Out:
# 313/313 - 1s - loss: 0.0809 - accuracy: 0.9783 - 758ms/epoch - 2ms/step
# 313/313 - 0s - loss: 0.0809 - accuracy: 0.9783 - 270ms/epoch - 861us/step
# 1/1 [==============================] - 0s 31ms/step
# Predicted probabilities for image 0:
# [[7.9222239e-08 9.8342362e-08 1.8417199e-06 2.0855814e-06 9.5060466e-09
#   1.6777474e-07 4.5076184e-10 9.9999475e-01 7.9317140e-09 1.0926232e-06]]
# Predicted class: 7
# 1/1 [==============================] - 0s 16ms/step
# Predicted probabilities for image 1:
# [[7.1482913e-09 1.7988378e-06 9.9999714e-01 1.0168932e-06 1.9240399e-12
#   1.6138499e-09 5.8342207e-09 1.0946090e-09 2.7590621e-09 2.0149713e-14]]
# Predicted class: 2
# 1/1 [==============================] - 0s 17ms/step
# Predicted probabilities for image 2:
# [[1.0125015e-07 9.9993443e-01 1.9434970e-06 1.0073109e-06 8.1592771e-06
#   9.1181556e-07 1.3500884e-06 4.6292418e-05 5.0232907e-06 7.5138712e-07]]
# Predicted class: 1
# 1/1 [==============================] - 0s 24ms/step
# ...
